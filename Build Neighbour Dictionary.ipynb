# %%
import pandas as pd

# %%
mile25 = pd.read_csv('data/sf12010countydistance25miles.csv', encoding = "ISO-8859-1")
mile25
# Out:
#       county1      countyname1  mi_to_county  county2           countyname2
# 0        1001   Autauga County     22.462994     1021        Chilton County
# 1        1003   Baldwin County     24.419671    12033       Escambia County
# 2        1005   Barbour County     23.254040    13239        Quitman County
# 3        1005   Barbour County     24.265804     1011        Bullock County
# 4        1009    Blount County     20.318000     1043        Cullman County
# ...       ...              ...           ...      ...                   ...
# 8379    72153  Yauco Municipio     23.707777    72023   Cabo Rojo Municipio
# 8380    72153  Yauco Municipio     24.816906    72075  Juana Díaz Municipio
# 8381    72153  Yauco Municipio     24.904720    72027       Camuy Municipio
# 8382    72153  Yauco Municipio     24.914280    72065     Hatillo Municipio
# 8383    72153  Yauco Municipio     24.937535    72099        Moca Municipio
#
# [8384 rows x 5 columns]

# %%
mile25.groupby('countyname1')['countyname2'].apply(list).to_dict()
# Out:
# {'Abbeville County': ['Greenwood County',
#   'Elbert County',
#   'McCormick County',
#   'Anderson County'],
#  'Acadia Parish': ['Lafayette Parish', 'Jefferson Davis Parish'],
#  'Accomack County': ['Somerset County'],
#  'Adair County': ['Cass County',
#   'Union County',
#   'Madison County',
#   'Adams County',
#   'Guthrie County',
#   'Russell County',
#   'Taylor County',
#   'Green County',
#   'Metcalfe County',
#   'Cumberland County',
#   'Casey County',
#   'Schuyler County',
#   'Knox County',
#   'Cherokee County',
#   'Washington County'],
#  'Adams County': ['Arapahoe County',
#   'Brown County',
#   'Wells County',
#   'Van Wert County',
#   'Mercer County',
#   'Jay County',
#   'Allen County',
#   'Taylor County',
#   'Union County',
#   'Montgomery County',
#   'Adair County',
#   'Cass County',
#   'Concordia Parish',
#   'Wilkinson County',
#   'Jefferson County',
#   'Webster County',
#   'Kearney County',
#   'Clay County',
#   'Hall County',
#   'Hettinger County',
#   'Brown County',
#   'Lewis County',
#   'Highland County',
#   'Cumberland County',
#   'Carroll County',
#   'Juneau County',
#   'Marquette County'],
#  'Adjuntas Municipio': ['Utuado Municipio',
#   'Yauco Municipio',
#   'Lares Municipio',
#   'Peñuelas Municipio',
#   'Jayuya Municipio',
#   'Maricao Municipio',
#   'Guayanilla Municipio',
#   'Sabana Grande Municipio',
#   'Las Marías Municipio',
#   'Ponce Municipio',
#   'San Sebastián Municipio',
#   'Ciales Municipio',
#   'Hatillo Municipio',
#   'Arecibo Municipio',
#   'Florida Municipio',
#   'San Germán Municipio',
#   'Villalba Municipio',
#   'Guánica Municipio',
#   'Camuy Municipio',
#   'Orocovis Municipio',
#   'Juana Díaz Municipio',
#   'Quebradillas Municipio',
#   'Lajas Municipio',
#   'Hormigueros Municipio',
#   'Barceloneta Municipio',
#   'Morovis Municipio'],
#  'Aguada Municipio': ['Rincón Municipio',
#   'Moca Municipio',
#   'Añasco Municipio',
#   'Aguadilla Municipio',
#   'Isabela Municipio',
#   'San Sebastián Municipio',
#   'Las Marías Municipio',
#   'Hormigueros Municipio',
#   'Quebradillas Municipio',
#   'San Germán Municipio',
#   'Maricao Municipio',
#   'Camuy Municipio',
#   'Lares Municipio'],
#  'Aguadilla Municipio': ['Aguada Municipio',
#   'Moca Municipio',
#   'Isabela Municipio',
#   'Rincón Municipio',
#   'Añasco Municipio',
#   'Quebradillas Municipio',
#   'San Sebastián Municipio',
#   'Camuy Municipio',
#   'Las Marías Municipio',
#   'Hatillo Municipio',
#   'Lares Municipio',
#   'Hormigueros Municipio'],
#  'Aguas Buenas Municipio': ['Caguas Municipio',
#   'Cidra Municipio',
#   'Guaynabo Municipio',
#   'Comerío Municipio',
#   'Bayamón Municipio',
#   'Naranjito Municipio',
#   'Gurabo Municipio',
#   'Trujillo Alto Municipio',
#   'Toa Alta Municipio',
#   'Cayey Municipio',
#   'San Juan Municipio',
#   'Aibonito Municipio',
#   'San Lorenzo Municipio',
#   'Barranquitas Municipio',
#   'Cataño Municipio',
#   'Corozal Municipio',
#   'Carolina Municipio',
#   'Toa Baja Municipio',
#   'Juncos Municipio',
#   'Canóvanas Municipio',
#   'Dorado Municipio',
#   'Las Piedras Municipio',
#   'Coamo Municipio',
#   'Vega Alta Municipio',
#   'Morovis Municipio',
#   'Guayama Municipio',
#   'Patillas Municipio',
#   'Orocovis Municipio',
#   'Arroyo Municipio',
#   'Loíza Municipio',
#   'Salinas Municipio',
#   'Yabucoa Municipio',
#   'Vega Baja Municipio',
#   'Río Grande Municipio',
#   'Maunabo Municipio',
#   'Humacao Municipio',
#   'Villalba Municipio'],
#  'Aibonito Municipio': ['Barranquitas Municipio',
#   'Coamo Municipio',
#   'Comerío Municipio',
#   'Cidra Municipio',
#   'Cayey Municipio',
#   'Salinas Municipio',
#   'Naranjito Municipio',
#   'Aguas Buenas Municipio',
#   'Orocovis Municipio',
#   'Corozal Municipio',
#   'Guayama Municipio',
#   'Villalba Municipio',
#   'Santa Isabel Municipio',
#   'Caguas Municipio',
#   'Toa Alta Municipio',
#   'Bayamón Municipio',
#   'Morovis Municipio',
#   'Juana Díaz Municipio',
#   'Guaynabo Municipio',
#   'Arroyo Municipio',
#   'San Lorenzo Municipio',
#   'Ciales Municipio',
#   'Patillas Municipio',
#   'Gurabo Municipio',
#   'Vega Alta Municipio',
#   'Jayuya Municipio',
#   'Trujillo Alto Municipio',
#   'Cataño Municipio',
#   'Toa Baja Municipio',
#   'Dorado Municipio',
#   'San Juan Municipio',
#   'Vega Baja Municipio',
#   'Ponce Municipio',
#   'Juncos Municipio'],
#  'Aiken County': ['Barnwell County', 'Edgefield County'],
#  'Alachua County': ['Bradford County'],
#  'Alamance County': ['Orange County',
#   'Guilford County',
#   'Caswell County',
#   'Chatham County'],
#  'Alameda County': ['Contra Costa County'],
#  'Albany County': ['Schenectady County',
#   'Greene County',
#   'Schoharie County',
#   'Rensselaer County'],
#  'Albemarle County': ['Charlottesville city',
#   'Waynesboro city',
#   'Greene County',
#   'Fluvanna County',
#   'Nelson County'],
#  'Alcona County': ['Iosco County'],
#  'Alcorn County': ['Prentiss County',
#   'McNairy County',
#   'Tippah County',
#   'Tishomingo County'],
#  'Alexander County': ['Pulaski County',
#   'Scott County',
#   'Union County',
#   'Ballard County',
#   'Cape Girardeau County',
#   'Mississippi County',
#   'Catawba County',
#   'Iredell County',
#   'Caldwell County',
#   'Wilkes County'],
#  'Alexandria city': ['Arlington County',
#   'Falls Church city',
#   'District of Columbia',
#   'Fairfax County',
#   'Fairfax city',
#   "Prince George's County",
#   'Manassas Park city',
#   'Manassas city',
#   'Prince William County',
#   'Montgomery County',
#   'Charles County'],
#  'Allamakee County': ['Crawford County', 'Winneshiek County'],
#  'Allegan County': ['Ottawa County'],
#  'Allegany County': ['Mineral County', 'Hampshire County', 'Morgan County'],
#  'Alleghany County': ['Grayson County',
#   'Galax city',
#   'Wilkes County',
#   'Ashe County',
#   'Covington city',
#   'Botetourt County',
#   'Bath County',
#   'Craig County'],
#  'Allegheny County': ['Washington County', 'Beaver County'],
#  'Allen County': ['DeKalb County',
#   'Whitley County',
#   'Adams County',
#   'Neosho County',
#   'Anderson County',
#   'Bourbon County',
#   'Woodson County',
#   'Macon County',
#   'Barren County',
#   'Warren County',
#   'Simpson County',
#   'Sumner County',
#   'Trousdale County',
#   'Auglaize County',
#   'Putnam County',
#   'Hardin County'],
#  'Allendale County': ['Hampton County',
#   'Barnwell County',
#   'Screven County',
#   'Bamberg County'],
#  'Alpine County': ['Douglas County'],
#  'Amador County': ['Calaveras County', 'El Dorado County'],
#  'Amelia County': ['Nottoway County',
#   'Powhatan County',
#   'Cumberland County',
#   'Chesterfield County'],
#  'Amherst County': ['Buena Vista city',
#   'Lynchburg city',
#   'Nelson County',
#   'Lexington city',
#   'Rockbridge County'],
#  'Amite County': ['Franklin County', 'Pike County'],
#  'Anderson County': ['Allen County',
#   'Franklin County',
#   'Coffey County',
#   'Linn County',
#   'Woodford County',
#   'Mercer County',
#   'Franklin County',
#   'Spencer County',
#   'Washington County',
#   'Shelby County',
#   'Jessamine County',
#   'Hart County',
#   'Abbeville County',
#   'Knox County',
#   'Campbell County',
#   'Union County',
#   'Morgan County'],
#  'Andrew County': ['DeKalb County',
#   'Buchanan County',
#   'Doniphan County',
#   'Holt County'],
#  'Anne Arundel County': ["Prince George's County", 'Baltimore city'],
#  'Anoka County': ['Ramsey County',
#   'Isanti County',
#   'Hennepin County',
#   'Chisago County',
#   'Washington County'],
#  'Anson County': ['Richmond County',
#   'Chesterfield County',
#   'Union County',
#   'Stanly County'],
#  'Antelope County': ['Pierce County'],
#  'Antrim County': ['Kalkaska County'],
#  'Appanoose County': ['Monroe County',
#   'Putnam County',
#   'Davis County',
#   'Wayne County'],
#  'Appling County': ['Bacon County', 'Jeff Davis County', 'Tattnall County'],
#  'Appomattox County': ['Campbell County',
#   'Buckingham County',
#   'Lynchburg city',
#   'Prince Edward County'],
#  'Aransas County': ['Refugio County'],
#  'Arapahoe County': ['Adams County'],
#  'Arecibo Municipio': ['Barceloneta Municipio',
#   'Hatillo Municipio',
#   'Florida Municipio',
#   'Utuado Municipio',
#   'Manatí Municipio',
#   'Camuy Municipio',
#   'Ciales Municipio',
#   'Jayuya Municipio',
#   'Quebradillas Municipio',
#   'Lares Municipio',
#   'Vega Baja Municipio',
#   'Adjuntas Municipio',
#   'Morovis Municipio',
#   'San Sebastián Municipio',
#   'Orocovis Municipio',
#   'Vega Alta Municipio',
#   'Isabela Municipio',
#   'Las Marías Municipio',
#   'Corozal Municipio',
#   'Maricao Municipio',
#   'Villalba Municipio'],
#  'Arlington County': ['Falls Church city',
#   'Alexandria city',
#   'District of Columbia',
#   'Fairfax County',
#   'Fairfax city',
#   "Prince George's County",
#   'Montgomery County',
#   'Manassas Park city',
#   'Manassas city',
#   'Prince William County'],
#  'Armstrong County': ['Indiana County', 'Butler County'],
#  'Arroyo Municipio': ['Patillas Municipio',
#   'Guayama Municipio',
#   'Maunabo Municipio',
#   'Cayey Municipio',
#   'San Lorenzo Municipio',
#   'Yabucoa Municipio',
#   'Salinas Municipio',
#   'Cidra Municipio',
#   'Caguas Municipio',
#   'Aibonito Municipio',
#   'Las Piedras Municipio',
#   'Juncos Municipio',
#   'Humacao Municipio',
#   'Aguas Buenas Municipio',
#   'Comerío Municipio',
#   'Gurabo Municipio',
#   'Coamo Municipio',
#   'Santa Isabel Municipio',
#   'Barranquitas Municipio'],
#  'Arthur County': ['Grant County'],
#  'Ascension Parish': ['St. James Parish',
#   'Livingston Parish',
#   'Assumption Parish',
#   'St. John the Baptist Parish'],
#  'Ashe County': ['Watauga County',
#   'Johnson County',
#   'Alleghany County',
#   'Grayson County',
#   'Wilkes County'],
#  'Ashland County': ['Richland County', 'Wayne County', 'Iron County'],
#  'Asotin County': ['Garfield County', 'Nez Perce County'],
#  'Assumption Parish': ['St. James Parish', 'Ascension Parish'],
#  'Atchison County': ['Doniphan County',
#   'Jefferson County',
#   'Brown County',
#   'Nemaha County',
#   'Fremont County'],
#  'Athens County': ['Meigs County', 'Morgan County', 'Vinton County'],
#  'Atkinson County': ['Coffee County', 'Berrien County', 'Lanier County'],
#  'Atoka County': ['Coal County'],
#  'Attala County': ['Leake County'],
#  'Audrain County': ['Monroe County'],
#  'Audubon County': ['Guthrie County',
#   'Shelby County',
#   'Cass County',
#   'Carroll County'],
#  'Auglaize County': ['Shelby County', 'Allen County', 'Mercer County'],
#  'Augusta County': ['Staunton city', 'Waynesboro city', 'Harrisonburg city'],
#  'Aurora County': ['Davison County', 'Jerauld County'],
#  'Austin County': ['Waller County', 'Washington County', 'Colorado County'],
#  'Autauga County': ['Chilton County'],
#  'Avery County': ['Mitchell County',
#   'Watauga County',
#   'Carter County',
#   'Caldwell County',
#   'Yancey County'],
#  'Añasco Municipio': ['Aguada Municipio',
#   'Moca Municipio',
#   'Rincón Municipio',
#   'Hormigueros Municipio',
#   'Las Marías Municipio',
#   'San Sebastián Municipio',
#   'Aguadilla Municipio',
#   'San Germán Municipio',
#   'Maricao Municipio',
#   'Isabela Municipio',
#   'Lares Municipio',
#   'Quebradillas Municipio',
#   'Sabana Grande Municipio',
#   'Cabo Rojo Municipio',
#   'Camuy Municipio',
#   'Lajas Municipio',
#   'Yauco Municipio',
#   'Hatillo Municipio'],
#  'Bacon County': ['Appling County', 'Pierce County', 'Jeff Davis County'],
#  'Baker County': ['Union County',
#   'Columbia County',
#   'Mitchell County',
#   'Calhoun County',
#   'Miller County',
#   'Dougherty County'],
#  'Baldwin County': ['Escambia County',
#   'Jones County',
#   'Wilkinson County',
#   'Putnam County',
#   'Hancock County'],
#  'Ballard County': ['Pulaski County',
#   'Carlisle County',
#   'McCracken County',
#   'Massac County',
#   'Alexander County',
#   'Mississippi County'],
#  'Baltimore County': ['Baltimore city',
#   'Harford County',
#   'Howard County',
#   'Carroll County'],
#  'Baltimore city': ['Baltimore County',
#   'Howard County',
#   'Anne Arundel County',
#   'Harford County'],
#  'Bamberg County': ['Orangeburg County',
#   'Barnwell County',
#   'Allendale County'],
#  'Bandera County': ['Kerr County'],
#  'Banks County': ['Jackson County',
#   'Franklin County',
#   'Stephens County',
#   'Hall County',
#   'Habersham County',
#   'Madison County',
#   'White County'],
#  'Banner County': ['Scotts Bluff County', 'Kimball County'],
#  'Barbour County': ['Quitman County',
#   'Bullock County',
#   'Taylor County',
#   'Upshur County',
#   'Harrison County',
#   'Tucker County'],
#  'Barceloneta Municipio': ['Manatí Municipio',
#   'Florida Municipio',
#   'Arecibo Municipio',
#   'Vega Baja Municipio',
#   'Ciales Municipio',
#   'Morovis Municipio',
#   'Vega Alta Municipio',
#   'Hatillo Municipio',
#   'Utuado Municipio',
#   'Jayuya Municipio',
#   'Corozal Municipio',
#   'Orocovis Municipio',
#   'Dorado Municipio',
#   'Camuy Municipio',
#   'Toa Alta Municipio',
#   'Naranjito Municipio',
#   'Adjuntas Municipio',
#   'Toa Baja Municipio',
#   'Villalba Municipio',
#   'Quebradillas Municipio',
#   'Lares Municipio',
#   'Barranquitas Municipio'],
#  'Barnwell County': ['Allendale County', 'Bamberg County', 'Aiken County'],
#  'Barranquitas Municipio': ['Aibonito Municipio',
#   'Comerío Municipio',
#   'Naranjito Municipio',
#   'Coamo Municipio',
#   'Corozal Municipio',
#   'Orocovis Municipio',
#   'Cidra Municipio',
#   'Morovis Municipio',
#   'Villalba Municipio',
#   'Toa Alta Municipio',
#   'Cayey Municipio',
#   'Aguas Buenas Municipio',
#   'Bayamón Municipio',
#   'Ciales Municipio',
#   'Salinas Municipio',
#   'Guaynabo Municipio',
#   'Vega Alta Municipio',
#   'Caguas Municipio',
#   'Santa Isabel Municipio',
#   'Jayuya Municipio',
#   'Juana Díaz Municipio',
#   'Vega Baja Municipio',
#   'Dorado Municipio',
#   'Guayama Municipio',
#   'Toa Baja Municipio',
#   'Cataño Municipio',
#   'Florida Municipio',
#   'Manatí Municipio',
#   'San Juan Municipio',
#   'Gurabo Municipio',
#   'San Lorenzo Municipio',
#   'Trujillo Alto Municipio',
#   'Arroyo Municipio',
#   'Ponce Municipio',
#   'Barceloneta Municipio'],
#  'Barren County': ['Metcalfe County',
#   'Monroe County',
#   'Allen County',
#   'Hart County',
#   'Edmonson County'],
#  'Barrow County': ['Jackson County',
#   'Walton County',
#   'Gwinnett County',
#   'Oconee County',
#   'Clarke County',
#   'Hall County'],
#  'Barry County': ['Eaton County', 'Stone County'],
#  'Bartholomew County': ['Brown County',
#   'Jennings County',
#   'Jackson County',
#   'Decatur County',
#   'Johnson County',
#   'Shelby County'],
#  'Barton County': ['Jasper County', 'Vernon County'],
#  'Bartow County': ['Gordon County',
#   'Cherokee County',
#   'Floyd County',
#   'Paulding County',
#   'Pickens County'],
#  'Bastrop County': ['Travis County'],
#  'Bath County': ['Montgomery County',
#   'Fleming County',
#   'Menifee County',
#   'Rowan County',
#   'Nicholas County',
#   'Powell County',
#   'Highland County',
#   'Rockbridge County',
#   'Pocahontas County',
#   'Covington city',
#   'Alleghany County'],
#  'Baxter County': ['Marion County'],
#  'Bay County': ['Midland County'],
#  'Bayamón Municipio': ['Guaynabo Municipio',
#   'Toa Alta Municipio',
#   'Cataño Municipio',
#   'Aguas Buenas Municipio',
#   'Naranjito Municipio',
#   'Toa Baja Municipio',
#   'San Juan Municipio',
#   'Comerío Municipio',
#   'Dorado Municipio',
#   'Corozal Municipio',
#   'Trujillo Alto Municipio',
#   'Cidra Municipio',
#   'Caguas Municipio',
#   'Vega Alta Municipio',
#   'Gurabo Municipio',
#   'Carolina Municipio',
#   'Barranquitas Municipio',
#   'Aibonito Municipio',
#   'Morovis Municipio',
#   'Vega Baja Municipio',
#   'Cayey Municipio',
#   'Canóvanas Municipio',
#   'San Lorenzo Municipio',
#   'Juncos Municipio',
#   'Loíza Municipio',
#   'Orocovis Municipio',
#   'Coamo Municipio',
#   'Manatí Municipio',
#   'Las Piedras Municipio',
#   'Ciales Municipio',
#   'Río Grande Municipio'],
#  'Beaufort County': ['Jasper County'],
#  'Beaver County': ['Hancock County',
#   'Lawrence County',
#   'Columbiana County',
#   'Allegheny County'],
#  'Beckham County': ['Greer County'],
#  'Bedford County': ['Fulton County',
#   'Moore County',
#   'Marshall County',
#   'Coffee County',
#   'Rutherford County',
#   'Bedford city',
#   'Lynchburg city',
#   'Botetourt County',
#   'Roanoke city',
#   'Campbell County'],
#  'Bedford city': ['Bedford County',
#   'Lynchburg city',
#   'Botetourt County',
#   'Roanoke city',
#   'Campbell County'],
#  'Bee County': ['Live Oak County'],
#  'Belknap County': ['Merrimack County'],
#  'Bell County': ['Knox County', 'Claiborne County'],
#  'Belmont County': ['Ohio County',
#   'Marshall County',
#   'Harrison County',
#   'Monroe County'],
#  'Ben Hill County': ['Irwin County',
#   'Telfair County',
#   'Coffee County',
#   'Wilcox County'],
#  'Bennington County': ['Windham County'],
#  'Benton County': ['McDonald County',
#   'Warren County',
#   'Newton County',
#   'Linn County',
#   'Tama County',
#   'Sherburne County',
#   'Mille Lacs County',
#   'Tippah County',
#   'Marshall County',
#   'Union County',
#   'Morgan County',
#   'Humphreys County',
#   'Henry County',
#   'Carroll County'],
#  'Benzie County': ['Manistee County'],
#  'Bergen County': ['Passaic County',
#   'New York County',
#   'Rockland County',
#   'Bronx County',
#   'Essex County',
#   'Hudson County',
#   'Westchester County',
#   'Kings County',
#   'Union County',
#   'Queens County'],
#  'Berkeley County': ['Morgan County',
#   'Jefferson County',
#   'Washington County',
#   'Winchester city',
#   'Frederick County',
#   'Clarke County'],
#  'Berks County': ['Lehigh County'],
#  'Berkshire County': ['Columbia County'],
#  'Bernalillo County': ['Valencia County'],
#  'Berrien County': ['Cook County',
#   'Lanier County',
#   'Atkinson County',
#   'Tift County',
#   'Irwin County',
#   'LaPorte County'],
#  'Bertie County': ['Martin County', 'Chowan County', 'Hertford County'],
#  'Bibb County': ['Jones County',
#   'Crawford County',
#   'Peach County',
#   'Twiggs County',
#   'Monroe County',
#   'Houston County'],
#  'Bienville Parish': ['Red River Parish'],
#  'Big Stone County': ['Stevens County', 'Traverse County', 'Grant County'],
#  'Billings County': ['Golden Valley County'],
#  'Black Hawk County': ['Bremer County', 'Buchanan County'],
#  'Blackford County': ['Jay County',
#   'Delaware County',
#   'Grant County',
#   'Wells County'],
#  'Bladen County': ['Columbus County'],
#  'Blaine County': ['Loup County'],
#  'Blair County': ['Huntingdon County', 'Cambria County'],
#  'Bland County': ['Wythe County',
#   'Mercer County',
#   'Pulaski County',
#   'Tazewell County'],
#  'Bleckley County': ['Pulaski County',
#   'Twiggs County',
#   'Houston County',
#   'Dodge County',
#   'Laurens County'],
#  'Bledsoe County': ['Rhea County',
#   'Van Buren County',
#   'Sequatchie County',
#   'Meigs County'],
#  'Blount County': ['Cullman County',
#   'St. Clair County',
#   'Knox County',
#   'Loudon County',
#   'Sevier County',
#   'Graham County',
#   'Monroe County'],
#  'Blue Earth County': ['Waseca County', 'Nicollet County'],
#  'Bolivar County': ['Desha County', 'Sunflower County'],
#  'Bollinger County': ['Cape Girardeau County', 'Madison County'],
#  'Bon Homme County': ['Knox County'],
#  'Bond County': ['Clinton County', 'Montgomery County', 'Fayette County'],
#  'Boone County': ['Marion County',
#   'Taney County',
#   'Winnebago County',
#   'McHenry County',
#   'Clinton County',
#   'Hendricks County',
#   'Montgomery County',
#   'Hamilton County',
#   'Greene County',
#   'Story County',
#   'Dallas County',
#   'Kenton County',
#   'Ohio County',
#   'Gallatin County',
#   'Dearborn County',
#   'Hamilton County',
#   'Campbell County',
#   'Switzerland County',
#   'Grant County',
#   'Howard County',
#   'Callaway County',
#   'Nance County',
#   'Logan County',
#   'Lincoln County',
#   'Kanawha County'],
#  'Bosque County': ['Somervell County'],
#  'Bossier Parish': ['Webster Parish', 'Caddo Parish'],
#  'Botetourt County': ['Covington city',
#   'Alleghany County',
#   'Roanoke city',
#   'Bedford city',
#   'Bedford County',
#   'Salem city',
#   'Craig County'],
#  'Boulder County': ['Gilpin County', 'Broomfield County'],
#  'Bourbon County': ['Crawford County',
#   'Allen County',
#   'Linn County',
#   'Nicholas County',
#   'Clark County',
#   'Fayette County',
#   'Harrison County',
#   'Montgomery County',
#   'Scott County',
#   'Robertson County'],
#  'Bowie County': ['Little River County'],
#  'Bowman County': ['Slope County'],
#  'Boyd County': ['Lawrence County',
#   'Greenup County',
#   'Lawrence County',
#   'Carter County',
#   'Wayne County',
#   'Cabell County',
#   'Charles Mix County'],
#  'Boyle County': ['Mercer County',
#   'Lincoln County',
#   'Garrard County',
#   'Washington County',
#   'Casey County',
#   'Marion County',
#   'Jessamine County'],
#  'Bracken County': ['Robertson County',
#   'Pendleton County',
#   'Mason County',
#   'Harrison County',
#   'Brown County',
#   'Campbell County',
#   'Nicholas County'],
#  'Bradford County': ['Union County',
#   'Clay County',
#   'Alachua County',
#   'Sullivan County'],
#  'Bradley County': ['Calhoun County',
#   'Polk County',
#   'Hamilton County',
#   'McMinn County',
#   'Catoosa County',
#   'Meigs County'],
#  'Branch County': ['Steuben County',
#   'Hillsdale County',
#   'Calhoun County',
#   'St. Joseph County'],
#  'Brantley County': ['Pierce County', 'Wayne County'],
#  'Braxton County': ['Gilmer County',
#   'Webster County',
#   'Calhoun County',
#   'Lewis County'],
#  'Brazos County': ['Grimes County', 'Burleson County'],
#  'Breathitt County': ['Wolfe County',
#   'Magoffin County',
#   'Perry County',
#   'Owsley County',
#   'Lee County',
#   'Knott County'],
#  'Breckinridge County': ['Meade County',
#   'Hancock County',
#   'Grayson County',
#   'Perry County'],
#  'Bremer County': ['Chickasaw County', 'Black Hawk County', 'Butler County'],
#  'Bristol County': ['Bristol County',
#   'Newport County',
#   'Plymouth County',
#   'Bristol County',
#   'Newport County',
#   'Kent County',
#   'Providence County'],
#  'Bristol city': ['Sullivan County',
#   'Washington County',
#   'Johnson County',
#   'Russell County',
#   'Carter County'],
#  'Bronx County': ['New York County',
#   'Queens County',
#   'Bergen County',
#   'Hudson County',
#   'Kings County',
#   'Nassau County',
#   'Essex County',
#   'Westchester County',
#   'Rockland County',
#   'Richmond County'],
#  'Brooke County': ['Ohio County',
#   'Jefferson County',
#   'Hancock County',
#   'Washington County'],
#  'Brooks County': ['Lowndes County', 'Thomas County', 'Cook County'],
#  'Broome County': ['Susquehanna County', 'Tioga County'],
#  'Broomfield County': ['Denver County', 'Boulder County'],
#  'Brown County': ['Schuyler County',
#   'Adams County',
#   'Pike County',
#   'Monroe County',
#   'Bartholomew County',
#   'Jackson County',
#   'Johnson County',
#   'Morgan County',
#   'Richardson County',
#   'Doniphan County',
#   'Nemaha County',
#   'Atchison County',
#   'Watonwan County',
#   'Rock County',
#   'Clermont County',
#   'Bracken County',
#   'Adams County',
#   'Highland County',
#   'Mason County',
#   'Coleman County',
#   'Outagamie County'],
#  'Brule County': ['Buffalo County'],
#  'Brunswick County': ['New Hanover County',
#   'Greensville County',
#   'Emporia city',
#   'Lunenburg County',
#   'Dinwiddie County'],
#  'Bryan County': ['Liberty County', 'Chatham County', 'Effingham County'],
#  'Buchanan County': ['Black Hawk County',
#   'Delaware County',
#   'Platte County',
#   'Doniphan County',
#   'Clinton County',
#   'Andrew County',
#   'Dickenson County',
#   'McDowell County',
#   'Russell County',
#   'Pike County'],
#  'Buckingham County': ['Cumberland County',
#   'Appomattox County',
#   'Fluvanna County',
#   'Nelson County',
#   'Prince Edward County'],
#  'Bucks County': ['Montgomery County',
#   'Hunterdon County',
#   'Mercer County',
#   'Philadelphia County'],
#  'Buena Vista County': ['Clay County',
#   'Pocahontas County',
#   'Sac County',
#   'Cherokee County'],
#  'Buena Vista city': ['Lexington city',
#   'Rockbridge County',
#   'Amherst County',
#   'Lynchburg city'],
#  'Buffalo County': ['Brule County',
#   'Pepin County',
#   'Trempealeau County',
#   'Wabasha County'],
#  'Bullitt County': ['Jefferson County',
#   'Nelson County',
#   'Spencer County',
#   'Hardin County'],
#  'Bulloch County': ['Evans County', 'Candler County', 'Effingham County'],
#  'Bullock County': ['Macon County', 'Barbour County', 'Pike County'],
#  'Buncombe County': ['Henderson County', 'Madison County', 'Yancey County'],
#  'Bureau County': ['Putnam County'],
#  'Burke County': ['Jenkins County',
#   'Richmond County',
#   'Jefferson County',
#   'Caldwell County',
#   'McDowell County'],
#  'Burleson County': ['Brazos County', 'Washington County', 'Lee County'],
#  'Burlington County': ['Camden County', 'Ocean County'],
#  'Burt County': ['Washington County',
#   'Thurston County',
#   'Cuming County',
#   'Monona County',
#   'Dodge County'],
#  'Butler County': ['Crenshaw County',
#   'Floyd County',
#   'Grundy County',
#   'Bremer County',
#   'Franklin County',
#   'Warren County',
#   'Ohio County',
#   'Muhlenberg County',
#   'Clay County',
#   'Polk County',
#   'Colfax County',
#   'Seward County',
#   'Hamilton County',
#   'Preble County',
#   'Warren County',
#   'Union County',
#   'Lawrence County',
#   'Armstrong County'],
#  'Butts County': ['Jasper County',
#   'Henry County',
#   'Lamar County',
#   'Newton County',
#   'Monroe County',
#   'Spalding County'],
#  'Cabarrus County': ['Rowan County', 'Stanly County', 'Mecklenburg County'],
#  'Cabell County': ['Putnam County',
#   'Lincoln County',
#   'Lawrence County',
#   'Wayne County',
#   'Boyd County'],
#  'Cabo Rojo Municipio': ['Hormigueros Municipio',
#   'Lajas Municipio',
#   'San Germán Municipio',
#   'Sabana Grande Municipio',
#   'Guánica Municipio',
#   'Añasco Municipio',
#   'Maricao Municipio',
#   'Las Marías Municipio',
#   'Rincón Municipio',
#   'Yauco Municipio'],
#  'Caddo Parish': ['Bossier Parish'],
#  'Caguas Municipio': ['Aguas Buenas Municipio',
#   'Gurabo Municipio',
#   'San Lorenzo Municipio',
#   'Cidra Municipio',
#   'Trujillo Alto Municipio',
#   'Juncos Municipio',
#   'Cayey Municipio',
#   'Guaynabo Municipio',
#   'Comerío Municipio',
#   'Las Piedras Municipio',
#   'Bayamón Municipio',
#   'Canóvanas Municipio',
#   'Carolina Municipio',
#   'Naranjito Municipio',
#   'San Juan Municipio',
#   'Aibonito Municipio',
#   'Patillas Municipio',
#   'Yabucoa Municipio',
#   'Arroyo Municipio',
#   'Toa Alta Municipio',
#   'Barranquitas Municipio',
#   'Cataño Municipio',
#   'Guayama Municipio',
#   'Maunabo Municipio',
#   'Humacao Municipio',
#   'Corozal Municipio',
#   'Toa Baja Municipio',
#   'Río Grande Municipio',
#   'Loíza Municipio',
#   'Naguabo Municipio',
#   'Coamo Municipio',
#   'Salinas Municipio',
#   'Dorado Municipio',
#   'Vega Alta Municipio',
#   'Luquillo Municipio'],
#  'Calaveras County': ['Amador County'],
#  'Caldwell County': ['Lyon County',
#   'Crittenden County',
#   'Hopkins County',
#   'Trigg County',
#   'Daviess County',
#   'Clinton County',
#   'Ray County',
#   'Livingston County',
#   'Burke County',
#   'Alexander County',
#   'Watauga County',
#   'Avery County'],
#  'Calhoun County': ['Cleburne County',
#   'Etowah County',
#   'Cherokee County',
#   'Bradley County',
#   'Ouachita County',
#   'Liberty County',
#   'Baker County',
#   'Randolph County',
#   'Terrell County',
#   'Early County',
#   'Clay County',
#   'Dougherty County',
#   'Lincoln County',
#   'Jersey County',
#   'Greene County',
#   'Sac County',
#   'Webster County',
#   'Pocahontas County',
#   'Branch County',
#   'Yalobusha County',
#   'Chickasaw County',
#   'Webster County',
#   'Orangeburg County',
#   'Roane County',
#   'Gilmer County',
#   'Wirt County',
#   'Braxton County',
#   'Ritchie County'],
#  'Callaway County': ['Boone County'],
#  'Calloway County': ['Marshall County',
#   'Henry County',
#   'Graves County',
#   'Stewart County'],
#  'Calumet County': ['Winnebago County'],
#  'Calvert County': ["St. Mary's County", 'Talbot County'],
#  'Cambria County': ['Blair County', 'Indiana County'],
#  'Camden County': ['Glynn County',
#   'Nassau County',
#   'Miller County',
#   'Gloucester County',
#   'Burlington County',
#   'Philadelphia County',
#   'Delaware County',
#   'Pasquotank County',
#   'Currituck County',
#   'Perquimans County',
#   'Chesapeake city'],
#  'Cameron County': ['Elk County'],
#  'Camp County': ['Titus County',
#   'Upshur County',
#   'Morris County',
#   'Franklin County'],
#  'Campbell County': ['Kenton County',
#   'Clermont County',
#   'Pendleton County',
#   'Boone County',
#   'Hamilton County',
#   'Bracken County',
#   'Grant County',
#   'Walworth County',
#   'Scott County',
#   'Union County',
#   'Anderson County',
#   'Whitley County',
#   'Lynchburg city',
#   'Appomattox County',
#   'Bedford County',
#   'Bedford city'],
#  'Camuy Municipio': ['Hatillo Municipio',
#   'Quebradillas Municipio',
#   'Isabela Municipio',
#   'San Sebastián Municipio',
#   'Lares Municipio',
#   'Arecibo Municipio',
#   'Moca Municipio',
#   'Utuado Municipio',
#   'Las Marías Municipio',
#   'Aguadilla Municipio',
#   'Maricao Municipio',
#   'Adjuntas Municipio',
#   'Barceloneta Municipio',
#   'Florida Municipio',
#   'Añasco Municipio',
#   'Aguada Municipio',
#   'Jayuya Municipio',
#   'Manatí Municipio',
#   'Yauco Municipio'],
#  'Candler County': ['Emanuel County',
#   'Bulloch County',
#   'Evans County',
#   'Toombs County',
#   'Tattnall County'],
#  'Cannon County': ['DeKalb County',
#   'Warren County',
#   'Rutherford County',
#   'Coffee County'],
#  'Canóvanas Municipio': ['Río Grande Municipio',
#   'Carolina Municipio',
#   'Gurabo Municipio',
#   'Juncos Municipio',
#   'Trujillo Alto Municipio',
#   'Las Piedras Municipio',
#   'Loíza Municipio',
#   'Luquillo Municipio',
#   'Naguabo Municipio',
#   'San Juan Municipio',
#   'Caguas Municipio',
#   'San Lorenzo Municipio',
#   'Humacao Municipio',
#   'Guaynabo Municipio',
#   'Aguas Buenas Municipio',
#   'Bayamón Municipio',
#   'Cataño Municipio',
#   'Yabucoa Municipio',
#   'Fajardo Municipio',
#   'Cidra Municipio',
#   'Toa Baja Municipio',
#   'Maunabo Municipio',
#   'Comerío Municipio',
#   'Cayey Municipio',
#   'Ceiba Municipio',
#   'Toa Alta Municipio',
#   'Patillas Municipio',
#   'Naranjito Municipio'],
#  'Cape Girardeau County': ['Bollinger County',
#   'Alexander County',
#   'Perry County',
#   'Scott County',
#   'Union County'],
#  'Cape May County': ['Cumberland County'],
#  'Carbon County': ['Lehigh County',
#   'Monroe County',
#   'Luzerne County',
#   'Northampton County'],
#  'Carlisle County': ['Hickman County',
#   'Ballard County',
#   'Mississippi County',
#   'McCracken County',
#   'Graves County',
#   'Fulton County'],
#  'Carolina Municipio': ['Trujillo Alto Municipio',
#   'San Juan Municipio',
#   'Loíza Municipio',
#   'Canóvanas Municipio',
#   'Gurabo Municipio',
#   'Guaynabo Municipio',
#   'Río Grande Municipio',
#   'Cataño Municipio',
#   'Juncos Municipio',
#   'Bayamón Municipio',
#   'Caguas Municipio',
#   'Aguas Buenas Municipio',
#   'Toa Baja Municipio',
#   'Las Piedras Municipio',
#   'Luquillo Municipio',
#   'San Lorenzo Municipio',
#   'Toa Alta Municipio',
#   'Dorado Municipio',
#   'Cidra Municipio',
#   'Naguabo Municipio',
#   'Naranjito Municipio',
#   'Comerío Municipio',
#   'Humacao Municipio',
#   'Cayey Municipio',
#   'Vega Alta Municipio',
#   'Corozal Municipio',
#   'Yabucoa Municipio',
#   'Fajardo Municipio'],
#  'Caroline County': ["Queen Anne's County",
#   'Talbot County',
#   'Kent County',
#   'Spotsylvania County',
#   'King George County',
#   'Fredericksburg city',
#   'Hanover County',
#   'Essex County'],
#  'Carroll County': ['Madison County',
#   'Haralson County',
#   'Douglas County',
#   'Heard County',
#   'Coweta County',
#   'Whiteside County',
#   'Stephenson County',
#   'Cass County',
#   'White County',
#   'Clinton County',
#   'Tippecanoe County',
#   'Howard County',
#   'Greene County',
#   'Audubon County',
#   'Switzerland County',
#   'Trimble County',
#   'Henry County',
#   'Gallatin County',
#   'Jefferson County',
#   'Owen County',
#   'Ohio County',
#   'Frederick County',
#   'Howard County',
#   'Baltimore County',
#   'Adams County',
#   'Montgomery County',
#   'Leflore County',
#   'Grenada County',
#   'Holmes County',
#   'Livingston County',
#   'Harrison County',
#   'Columbiana County',
#   'Jefferson County',
#   'Stark County',
#   'Tuscarawas County',
#   'Henderson County',
#   'Benton County',
#   'Galax city',
#   'Surry County',
#   'Pulaski County',
#   'Wythe County',
#   'Patrick County'],
#  'Carson City': ['Douglas County', 'Storey County'],
#  'Carter County': ['Elliott County',
#   'Greenup County',
#   'Boyd County',
#   'Rowan County',
#   'Lewis County',
#   'Lawrence County',
#   'Ripley County',
#   'Murray County',
#   'Love County',
#   'Sullivan County',
#   'Avery County',
#   'Johnson County',
#   'Mitchell County',
#   'Washington County',
#   'Unicoi County',
#   'Bristol city',
#   'Watauga County'],
#  'Carteret County': ['Pamlico County'],
#  'Carver County': ['Scott County', 'Hennepin County', 'McLeod County'],
#  'Casey County': ['Lincoln County',
#   'Boyle County',
#   'Taylor County',
#   'Russell County',
#   'Pulaski County',
#   'Adair County',
#   'Marion County'],
#  'Cass County': ['Morgan County',
#   'Schuyler County',
#   'Menard County',
#   'Carroll County',
#   'Miami County',
#   'Fulton County',
#   'Howard County',
#   'Adair County',
#   'Audubon County',
#   'Montgomery County',
#   'Adams County',
#   'Elkhart County',
#   'St. Joseph County',
#   'Jackson County',
#   'Sarpy County',
#   'Otoe County',
#   'Marion County',
#   'Morris County'],
#  'Caswell County': ['Danville city', 'Person County', 'Alamance County'],
#  'Catahoula Parish': ['La Salle Parish', 'Concordia Parish'],
#  'Catawba County': ['Lincoln County', 'Alexander County', 'Iredell County'],
#  'Cataño Municipio': ['Toa Baja Municipio',
#   'San Juan Municipio',
#   'Bayamón Municipio',
#   'Guaynabo Municipio',
#   'Dorado Municipio',
#   'Toa Alta Municipio',
#   'Trujillo Alto Municipio',
#   'Carolina Municipio',
#   'Vega Alta Municipio',
#   'Naranjito Municipio',
#   'Aguas Buenas Municipio',
#   'Corozal Municipio',
#   'Comerío Municipio',
#   'Gurabo Municipio',
#   'Loíza Municipio',
#   'Vega Baja Municipio',
#   'Caguas Municipio',
#   'Cidra Municipio',
#   'Canóvanas Municipio',
#   'Morovis Municipio',
#   'Barranquitas Municipio',
#   'Juncos Municipio',
#   'Manatí Municipio',
#   'Aibonito Municipio',
#   'Río Grande Municipio',
#   'San Lorenzo Municipio',
#   'Cayey Municipio',
#   'Orocovis Municipio'],
#  'Catoosa County': ['Whitfield County',
#   'Walker County',
#   'Hamilton County',
#   'Dade County',
#   'Bradley County',
#   'Murray County'],
#  'Cayey Municipio': ['Cidra Municipio',
#   'Aibonito Municipio',
#   'Guayama Municipio',
#   'Comerío Municipio',
#   'Caguas Municipio',
#   'Aguas Buenas Municipio',
#   'Arroyo Municipio',
#   'Salinas Municipio',
#   'San Lorenzo Municipio',
#   'Barranquitas Municipio',
#   'Patillas Municipio',
#   'Coamo Municipio',
#   'Naranjito Municipio',
#   'Gurabo Municipio',
#   'Guaynabo Municipio',
#   'Bayamón Municipio',
#   'Corozal Municipio',
#   'Juncos Municipio',
#   'Maunabo Municipio',
#   'Santa Isabel Municipio',
#   'Trujillo Alto Municipio',
#   'Toa Alta Municipio',
#   'Yabucoa Municipio',
#   'Las Piedras Municipio',
#   'Orocovis Municipio',
#   'Villalba Municipio',
#   'San Juan Municipio',
#   'Morovis Municipio',
#   'Cataño Municipio',
#   'Canóvanas Municipio',
#   'Juana Díaz Municipio',
#   'Carolina Municipio',
#   'Humacao Municipio',
#   'Toa Baja Municipio'],
#  'Cayuga County': ['Onondaga County', 'Seneca County'],
#  'Cecil County': ['New Castle County', 'Harford County', 'Kent County'],
#  'Cedar County': ['Muscatine County',
#   'Jones County',
#   'Johnson County',
#   'Dade County',
#   'St. Clair County',
#   'Dixon County'],
#  'Ceiba Municipio': ['Fajardo Municipio',
#   'Vieques Municipio',
#   'Luquillo Municipio',
#   'Naguabo Municipio',
#   'Culebra Municipio',
#   'Río Grande Municipio',
#   'Humacao Municipio',
#   'Las Piedras Municipio',
#   'Canóvanas Municipio'],
#  'Centre County': ['Mifflin County'],
#  'Cerro Gordo County': ['Worth County',
#   'Franklin County',
#   'Floyd County',
#   'Hancock County'],
#  'Chambers County': ['Lee County', 'Troup County', 'Tallapoosa County'],
#  'Champaign County': ['Piatt County',
#   'Clark County',
#   'Logan County',
#   'Union County',
#   'Miami County'],
#  'Charles City County': ['New Kent County',
#   'Hopewell city',
#   'Henrico County',
#   'Prince George County',
#   'James City County',
#   'Surry County',
#   'Colonial Heights city',
#   'Williamsburg city',
#   'Petersburg city',
#   'King William County'],
#  'Charles County': ['King George County',
#   'Alexandria city',
#   'Stafford County'],
#  'Charles Mix County': ['Douglas County', 'Boyd County'],
#  'Charlevoix County': ['Emmet County'],
#  'Charlotte County': ['Lee County',
#   'DeSoto County',
#   'Prince Edward County',
#   'Halifax County',
#   'Lunenburg County'],
#  'Charlottesville city': ['Albemarle County',
#   'Greene County',
#   'Fluvanna County',
#   'Waynesboro city'],
#  'Chase County': ['Perkins County', 'Dundy County'],
#  'Chatham County': ['Bryan County',
#   'Liberty County',
#   'Lee County',
#   'Alamance County'],
#  'Chattahoochee County': ['Muscogee County',
#   'Marion County',
#   'Stewart County',
#   'Russell County',
#   'Webster County'],
#  'Chattooga County': ['Floyd County', 'Walker County'],
#  'Chautauqua County': ['Elk County'],
#  'Cheatham County': ['Dickson County',
#   'Davidson County',
#   'Robertson County',
#   'Montgomery County'],
#  'Chemung County': ['Schuyler County', 'Tioga County', 'Tompkins County'],
#  'Cherokee County': ['Etowah County',
#   'Calhoun County',
#   'Pickens County',
#   'Forsyth County',
#   'Bartow County',
#   'Cobb County',
#   'Dawson County',
#   "O'Brien County",
#   'Buena Vista County',
#   'Ottawa County',
#   'Crawford County',
#   'Labette County',
#   'Clay County',
#   'Graham County',
#   'Union County',
#   'Fannin County',
#   'Monroe County',
#   'Towns County',
#   'Adair County',
#   'Cleveland County',
#   'Spartanburg County',
#   'York County',
#   'Union County'],
#  'Chesapeake city': ['Portsmouth city',
#   'Virginia Beach city',
#   'Norfolk city',
#   'Suffolk city',
#   'Camden County'],
#  'Cheshire County': ['Windham County'],
#  'Chester County': ['Delaware County',
#   'York County',
#   'Fairfield County',
#   'McNairy County',
#   'Madison County',
#   'Henderson County'],
#  'Chesterfield County': ['Anson County',
#   'Darlington County',
#   'Richmond city',
#   'Colonial Heights city',
#   'Petersburg city',
#   'Henrico County',
#   'Hopewell city',
#   'Dinwiddie County',
#   'Amelia County',
#   'Powhatan County',
#   'Prince George County'],
#  'Chickasaw County': ['Bremer County',
#   'Howard County',
#   'Floyd County',
#   'Clay County',
#   'Pontotoc County',
#   'Calhoun County'],
#  'Chicot County': ['Washington County'],
#  'Childress County': ['Hall County'],
#  'Chilton County': ['Autauga County'],
#  'Chippewa County': ['Swift County', 'Eau Claire County'],
#  'Chisago County': ['Isanti County', 'Polk County', 'Anoka County'],
#  'Chittenden County': ['Lamoille County'],
#  'Choctaw County': ['Webster County',
#   'Winston County',
#   'Oktibbeha County',
#   'Montgomery County',
#   'Lamar County'],
#  'Chowan County': ['Perquimans County',
#   'Washington County',
#   'Bertie County',
#   'Pasquotank County',
#   'Gates County'],
#  'Christian County': ['Montgomery County',
#   'Todd County',
#   'Trigg County',
#   'Greene County',
#   'Stone County',
#   'Taney County'],
#  'Ciales Municipio': ['Florida Municipio',
#   'Morovis Municipio',
#   'Jayuya Municipio',
#   'Orocovis Municipio',
#   'Manatí Municipio',
#   'Villalba Municipio',
#   'Corozal Municipio',
#   'Utuado Municipio',
#   'Barceloneta Municipio',
#   'Vega Baja Municipio',
#   'Arecibo Municipio',
#   'Barranquitas Municipio',
#   'Vega Alta Municipio',
#   'Coamo Municipio',
#   'Naranjito Municipio',
#   'Adjuntas Municipio',
#   'Toa Alta Municipio',
#   'Comerío Municipio',
#   'Aibonito Municipio',
#   'Juana Díaz Municipio',
#   'Dorado Municipio',
#   'Ponce Municipio',
#   'Hatillo Municipio',
#   'Bayamón Municipio',
#   'Peñuelas Municipio',
#   'Lares Municipio',
#   'Toa Baja Municipio',
#   'Cidra Municipio',
#   'Santa Isabel Municipio'],
#  'Cidra Municipio': ['Cayey Municipio',
#   'Comerío Municipio',
#   'Aguas Buenas Municipio',
#   'Aibonito Municipio',
#   'Caguas Municipio',
#   'Barranquitas Municipio',
#   'Naranjito Municipio',
#   'Bayamón Municipio',
#   'Guaynabo Municipio',
#   'San Lorenzo Municipio',
#   'Gurabo Municipio',
#   'Coamo Municipio',
#   'Guayama Municipio',
#   'Corozal Municipio',
#   'Toa Alta Municipio',
#   'Trujillo Alto Municipio',
#   'Salinas Municipio',
#   'Arroyo Municipio',
#   'Patillas Municipio',
#   'Juncos Municipio',
#   'Orocovis Municipio',
#   'San Juan Municipio',
#   'Cataño Municipio',
#   'Las Piedras Municipio',
#   'Morovis Municipio',
#   'Toa Baja Municipio',
#   'Carolina Municipio',
#   'Villalba Municipio',
#   'Canóvanas Municipio',
#   'Maunabo Municipio',
#   'Yabucoa Municipio',
#   'Santa Isabel Municipio',
#   'Vega Alta Municipio',
#   'Dorado Municipio',
#   'Ciales Municipio',
#   'Humacao Municipio',
#   'Vega Baja Municipio',
#   'Juana Díaz Municipio'],
#  'Citrus County': ['Hernando County'],
#  'Claiborne County': ['Jefferson County',
#   'Bell County',
#   'Grainger County',
#   'Union County',
#   'Hancock County'],
#  'Claiborne Parish': ['Webster Parish', 'Lincoln Parish'],
#  'Clare County': ['Gladwin County', 'Isabella County', 'Osceola County'],
#  'Clarendon County': ['Sumter County'],
#  'Clarion County': ['Venango County', 'Jefferson County', 'Forest County'],
#  'Clark County': ['Hot Spring County',
#   'Vigo County',
#   'Crawford County',
#   'Edgar County',
#   'Cumberland County',
#   'Scott County',
#   'Oldham County',
#   'Floyd County',
#   'Jefferson County',
#   'Trimble County',
#   'Washington County',
#   'Montgomery County',
#   'Bourbon County',
#   'Fayette County',
#   'Madison County',
#   'Powell County',
#   'Estill County',
#   'Jessamine County',
#   'Lee County',
#   'Scotland County',
#   'Lewis County',
#   'Champaign County',
#   'Greene County',
#   'Madison County',
#   'Multnomah County'],
#  'Clarke County': ['Oconee County',
#   'Madison County',
#   'Jackson County',
#   'Oglethorpe County',
#   'Barrow County',
#   'Walton County',
#   'Decatur County',
#   'Lucas County',
#   'Union County',
#   'Madison County',
#   'Warren County',
#   'Lauderdale County',
#   'Winchester city',
#   'Jefferson County',
#   'Frederick County',
#   'Warren County',
#   'Loudoun County',
#   'Berkeley County'],
#  'Clatsop County': ['Wahkiakum County'],
#  'Clay County': ['Talladega County',
#   'Randolph County',
#   'Greene County',
#   'Butler County',
#   'Dunklin County',
#   'Bradford County',
#   'Henry County',
#   'Quitman County',
#   'Randolph County',
#   'Early County',
#   'Calhoun County',
#   'Effingham County',
#   'Richland County',
#   'Wayne County',
#   'Marion County',
#   'Vigo County',
#   'Owen County',
#   'Putnam County',
#   'Greene County',
#   'Dickinson County',
#   'Buena Vista County',
#   "O'Brien County",
#   'Palo Alto County',
#   'Riley County',
#   'Owsley County',
#   'Leslie County',
#   'Knox County',
#   'Laurel County',
#   'Jackson County',
#   'Oktibbeha County',
#   'Chickasaw County',
#   'Monroe County',
#   'Lowndes County',
#   'Platte County',
#   'Clinton County',
#   'Jackson County',
#   'Ray County',
#   'Wyandotte County',
#   'Adams County',
#   'Fillmore County',
#   'Nuckolls County',
#   'Hamilton County',
#   'Towns County',
#   'Cherokee County',
#   'Macon County',
#   'Union County',
#   'Graham County',
#   'Rabun County',
#   'Union County',
#   'Yankton County',
#   'Monroe County',
#   'Jackson County',
#   'Cumberland County',
#   'Overton County',
#   'Nicholas County',
#   'Roane County'],
#  'Clayton County': ['Fayette County',
#   'Henry County',
#   'Fulton County',
#   'DeKalb County',
#   'Spalding County',
#   'Douglas County',
#   'Rockdale County',
#   'Coweta County'],
#  'Clear Creek County': ['Gilpin County', 'Jefferson County'],
#  'Cleburne County': ['Calhoun County', 'Haralson County', 'Stone County'],
#  'Clermont County': ['Campbell County',
#   'Brown County',
#   'Kenton County',
#   'Hamilton County'],
#  'Cleveland County': ['Cherokee County',
#   'Rutherford County',
#   'Lincoln County',
#   'Gaston County',
#   'McClain County',
#   'Pottawatomie County',
#   'Oklahoma County'],
#  'Clinch County': ['Echols County', 'Ware County', 'Lanier County'],
#  'Clinton County': ['Washington County',
#   'Bond County',
#   'Boone County',
#   'Carroll County',
#   'Tipton County',
#   'Tippecanoe County',
#   'Howard County',
#   'Scott County',
#   'Jackson County',
#   'Pickett County',
#   'Cumberland County',
#   'Wayne County',
#   'Russell County',
#   'Shiawassee County',
#   'Gratiot County',
#   'Ionia County',
#   'DeKalb County',
#   'Clay County',
#   'Buchanan County',
#   'Caldwell County',
#   'Grand Isle County',
#   'Warren County',
#   'Greene County',
#   'Highland County',
#   'Fayette County'],
#  'Cloud County': ['Republic County', 'Ottawa County'],
#  'Coahoma County': ['Quitman County', 'Phillips County'],
#  'Coal County': ['Atoka County', 'Pontotoc County'],
#  'Coamo Municipio': ['Aibonito Municipio',
#   'Barranquitas Municipio',
#   'Villalba Municipio',
#   'Orocovis Municipio',
#   'Santa Isabel Municipio',
#   'Salinas Municipio',
#   'Juana Díaz Municipio',
#   'Comerío Municipio',
#   'Cayey Municipio',
#   'Cidra Municipio',
#   'Corozal Municipio',
#   'Naranjito Municipio',
#   'Morovis Municipio',
#   'Ciales Municipio',
#   'Jayuya Municipio',
#   'Guayama Municipio',
#   'Ponce Municipio',
#   'Aguas Buenas Municipio',
#   'Toa Alta Municipio',
#   'Bayamón Municipio',
#   'Caguas Municipio',
#   'Arroyo Municipio',
#   'Florida Municipio',
#   'Vega Alta Municipio',
#   'Guaynabo Municipio',
#   'Vega Baja Municipio',
#   'Peñuelas Municipio'],
#  'Cobb County': ['Fulton County',
#   'Paulding County',
#   'Douglas County',
#   'Cherokee County',
#   'DeKalb County'],
#  'Cocke County': ['Jefferson County',
#   'Hamblen County',
#   'Madison County',
#   'Greene County',
#   'Sevier County'],
#  'Codington County': ['Hamlin County'],
#  'Coffee County': ['Dale County',
#   'Geneva County',
#   'Atkinson County',
#   'Jeff Davis County',
#   'Ben Hill County',
#   'Moore County',
#   'Grundy County',
#   'Warren County',
#   'Bedford County',
#   'Cannon County',
#   'Franklin County'],
#  'Coffey County': ['Anderson County', 'Woodson County'],
#  'Coke County': ['Sterling County'],
#  'Colbert County': ['Lauderdale County',
#   'Franklin County',
#   'Tishomingo County'],
#  'Cole County': ['Moniteau County', 'Miller County', 'Osage County'],
#  'Coleman County': ['Brown County'],
#  'Coles County': ['Cumberland County', 'Douglas County', 'Moultrie County'],
#  'Colfax County': ['Platte County',
#   'Dodge County',
#   'Stanton County',
#   'Butler County'],
#  'Colleton County': ['Dorchester County'],
#  'Collin County': ['Rockwall County'],
#  'Colonial Heights city': ['Petersburg city',
#   'Hopewell city',
#   'Prince George County',
#   'Chesterfield County',
#   'Henrico County',
#   'Dinwiddie County',
#   'Richmond city',
#   'Charles City County',
#   'Sussex County'],
#  'Colorado County': ['Austin County'],
#  'Colquitt County': ['Cook County', 'Tift County', 'Thomas County'],
#  'Columbia County': ['Lafayette County',
#   'Union County',
#   'Baker County',
#   'Suwannee County',
#   'McDuffie County',
#   'Richmond County',
#   'Lincoln County',
#   'Edgefield County',
#   'McCormick County',
#   'Berkshire County',
#   'Montour County',
#   'Northumberland County',
#   'Luzerne County',
#   'Garfield County',
#   'Marquette County'],
#  'Columbiana County': ['Mahoning County',
#   'Hancock County',
#   'Carroll County',
#   'Beaver County'],
#  'Columbus County': ['Bladen County'],
#  'Comal County': ['Hays County', 'Guadalupe County'],
#  'Comerío Municipio': ['Naranjito Municipio',
#   'Cidra Municipio',
#   'Barranquitas Municipio',
#   'Aguas Buenas Municipio',
#   'Aibonito Municipio',
#   'Corozal Municipio',
#   'Bayamón Municipio',
#   'Cayey Municipio',
#   'Toa Alta Municipio',
#   'Guaynabo Municipio',
#   'Caguas Municipio',
#   'Coamo Municipio',
#   'Orocovis Municipio',
#   'Morovis Municipio',
#   'Cataño Municipio',
#   'Gurabo Municipio',
#   'Toa Baja Municipio',
#   'Trujillo Alto Municipio',
#   'Vega Alta Municipio',
#   'San Lorenzo Municipio',
#   'San Juan Municipio',
#   'Dorado Municipio',
#   'Salinas Municipio',
#   'Villalba Municipio',
#   'Guayama Municipio',
#   'Vega Baja Municipio',
#   'Ciales Municipio',
#   'Carolina Municipio',
#   'Juncos Municipio',
#   'Arroyo Municipio',
#   'Santa Isabel Municipio',
#   'Patillas Municipio',
#   'Las Piedras Municipio',
#   'Canóvanas Municipio',
#   'Manatí Municipio',
#   'Juana Díaz Municipio',
#   'Jayuya Municipio',
#   'Florida Municipio'],
#  'Concordia Parish': ['Adams County', 'Catahoula Parish'],
#  'Conecuh County': ['Escambia County'],
#  'Conejos County': ['Rio Grande County'],
#  'Contra Costa County': ['Alameda County', 'Solano County'],
#  'Conway County': ['Faulkner County', 'Pope County', 'Van Buren County'],
#  'Cook County': ['Berrien County',
#   'Colquitt County',
#   'Tift County',
#   'Lanier County',
#   'Brooks County',
#   'Lowndes County',
#   'DuPage County'],
#  'Cooke County': ['Love County'],
#  'Cooper County': ['Moniteau County', 'Howard County'],
#  'Coos County': ['Essex County'],
#  'Coosa County': ['Elmore County'],
#  'Copiah County': ['Lincoln County'],
#  'Corozal Municipio': ['Naranjito Municipio',
#   'Morovis Municipio',
#   'Toa Alta Municipio',
#   'Barranquitas Municipio',
#   'Comerío Municipio',
#   'Vega Alta Municipio',
#   'Orocovis Municipio',
#   'Bayamón Municipio',
#   'Vega Baja Municipio',
#   'Ciales Municipio',
#   'Dorado Municipio',
#   'Aibonito Municipio',
#   'Aguas Buenas Municipio',
#   'Toa Baja Municipio',
#   'Coamo Municipio',
#   'Cidra Municipio',
#   'Guaynabo Municipio',
#   'Manatí Municipio',
#   'Cataño Municipio',
#   'Villalba Municipio',
#   'Florida Municipio',
#   'Cayey Municipio',
#   'Jayuya Municipio',
#   'San Juan Municipio',
#   'Barceloneta Municipio',
#   'Caguas Municipio',
#   'Trujillo Alto Municipio',
# ...
#   'Benton County',
#   'Neshoba County',
#   'Scott County',
#   'McDonald County',
#   'Jasper County',
#   'Jasper County'],
#  'Nez Perce County': ['Lewis County', 'Asotin County'],
#  'Nicholas County': ['Robertson County',
#   'Bourbon County',
#   'Fleming County',
#   'Harrison County',
#   'Bath County',
#   'Mason County',
#   'Montgomery County',
#   'Bracken County',
#   'Clay County',
#   'Fayette County',
#   'Webster County'],
#  'Nicollet County': ['Sibley County', 'Blue Earth County'],
#  'Noble County': ['LaGrange County',
#   'Whitley County',
#   'DeKalb County',
#   'Monroe County',
#   'Guernsey County',
#   'Washington County',
#   'Morgan County'],
#  'Nobles County': ['Osceola County', 'Murray County', 'Rock County'],
#  'Norfolk County': ['Suffolk County', 'Middlesex County'],
#  'Norfolk city': ['Portsmouth city',
#   'Hampton city',
#   'Poquoson city',
#   'Virginia Beach city',
#   'Chesapeake city',
#   'Newport News city',
#   'York County'],
#  'Northampton County': ['Halifax County',
#   'Greensville County',
#   'Emporia city',
#   'Hertford County',
#   'Warren County',
#   'Lehigh County',
#   'Monroe County',
#   'Carbon County',
#   'Hunterdon County',
#   'Mathews County',
#   'Poquoson city'],
#  'Northumberland County': ['Montour County',
#   'Union County',
#   'Snyder County',
#   'Columbia County',
#   'Lancaster County',
#   'Middlesex County',
#   'Richmond County'],
#  'Norton city': ['Wise County',
#   'Scott County',
#   'Letcher County',
#   'Dickenson County'],
#  'Nottoway County': ['Amelia County',
#   'Lunenburg County',
#   'Prince Edward County',
#   'Dinwiddie County'],
#  'Nowata County': ['Washington County', 'Craig County'],
#  'Noxubee County': ['Kemper County'],
#  'Nuckolls County': ['Thayer County', 'Webster County', 'Clay County'],
#  'Nueces County': ['San Patricio County', 'Kleberg County'],
#  "O'Brien County": ['Osceola County', 'Cherokee County', 'Clay County'],
#  'Oakland County': ['Macomb County'],
#  'Obion County': ['Fulton County',
#   'Lake County',
#   'Hickman County',
#   'Weakley County'],
#  'Ocean County': ['Burlington County'],
#  'Oceana County': ['Mason County', 'Muskegon County'],
#  'Oconee County': ['Clarke County',
#   'Morgan County',
#   'Walton County',
#   'Barrow County',
#   'Oglethorpe County',
#   'Jackson County',
#   'Greene County',
#   'Madison County',
#   'Stephens County',
#   'Pickens County',
#   'Rabun County'],
#  'Oconto County': ['Menominee County'],
#  'Ogemaw County': ['Roscommon County', 'Oscoda County'],
#  'Ogle County': ['Lee County', 'Winnebago County'],
#  'Oglethorpe County': ['Clarke County',
#   'Madison County',
#   'Wilkes County',
#   'Greene County',
#   'Oconee County',
#   'Elbert County',
#   'Taliaferro County'],
#  'Ohio County': ['Switzerland County',
#   'Boone County',
#   'Gallatin County',
#   'Dearborn County',
#   'Ripley County',
#   'Carroll County',
#   'Kenton County',
#   'Butler County',
#   'Daviess County',
#   'McLean County',
#   'Muhlenberg County',
#   'Brooke County',
#   'Marshall County',
#   'Belmont County',
#   'Washington County',
#   'Jefferson County'],
#  'Okaloosa County': ['Walton County'],
#  'Okfuskee County': ['Okmulgee County'],
#  'Oklahoma County': ['Cleveland County', 'Logan County'],
#  'Okmulgee County': ['Okfuskee County'],
#  'Oktibbeha County': ['Clay County', 'Choctaw County'],
#  'Oldham County': ['Clark County',
#   'Trimble County',
#   'Shelby County',
#   'Jefferson County',
#   'Henry County'],
#  'Olmsted County': ['Wabasha County', 'Dodge County'],
#  'Oneida County': ['Vilas County'],
#  'Onondaga County': ['Cayuga County'],
#  'Onslow County': ['Jones County'],
#  'Ontario County': ['Yates County', 'Seneca County'],
#  'Orange County': ['Seminole County',
#   'Crawford County',
#   'Martin County',
#   'Lawrence County',
#   'Washington County',
#   'Dubois County',
#   'Rockland County',
#   'Durham County',
#   'Alamance County',
#   'Person County',
#   'Jefferson County',
#   'Washington County',
#   'Culpeper County',
#   'Madison County',
#   'Louisa County',
#   'Spotsylvania County'],
#  'Orangeburg County': ['Calhoun County', 'Bamberg County'],
#  'Orleans County': ['Lamoille County'],
#  'Orleans Parish': ['St. Tammany Parish'],
#  'Orocovis Municipio': ['Villalba Municipio',
#   'Morovis Municipio',
#   'Ciales Municipio',
#   'Barranquitas Municipio',
#   'Coamo Municipio',
#   'Corozal Municipio',
#   'Jayuya Municipio',
#   'Aibonito Municipio',
#   'Naranjito Municipio',
#   'Florida Municipio',
#   'Comerío Municipio',
#   'Juana Díaz Municipio',
#   'Toa Alta Municipio',
#   'Vega Alta Municipio',
#   'Manatí Municipio',
#   'Vega Baja Municipio',
#   'Utuado Municipio',
#   'Cidra Municipio',
#   'Santa Isabel Municipio',
#   'Ponce Municipio',
#   'Barceloneta Municipio',
#   'Bayamón Municipio',
#   'Cayey Municipio',
#   'Aguas Buenas Municipio',
#   'Salinas Municipio',
#   'Dorado Municipio',
#   'Adjuntas Municipio',
#   'Arecibo Municipio',
#   'Guaynabo Municipio',
#   'Toa Baja Municipio',
#   'Peñuelas Municipio',
#   'Cataño Municipio'],
#  'Osage County': ['Gasconade County', 'Maries County', 'Cole County'],
#  'Osceola County': ["O'Brien County",
#   'Nobles County',
#   'Dickinson County',
#   'Clare County',
#   'Lake County'],
#  'Oscoda County': ['Montmorency County', 'Crawford County', 'Ogemaw County'],
#  'Otoe County': ['Johnson County', 'Cass County', 'Nemaha County'],
#  'Otsego County': ['Montmorency County', 'Crawford County'],
#  'Ottawa County': ['Cloud County',
#   'Saline County',
#   'Allegan County',
#   'Muskegon County',
#   'Sandusky County',
#   'Craig County',
#   'Cherokee County'],
#  'Ouachita County': ['Calhoun County'],
#  'Ouachita Parish': ['Richland Parish'],
#  'Outagamie County': ['Brown County'],
#  'Overton County': ['Putnam County',
#   'Pickett County',
#   'Fentress County',
#   'Clay County',
#   'Jackson County'],
#  'Owen County': ['Clay County',
#   'Monroe County',
#   'Greene County',
#   'Morgan County',
#   'Putnam County',
#   'Henry County',
#   'Grant County',
#   'Gallatin County',
#   'Franklin County',
#   'Carroll County',
#   'Scott County',
#   'Switzerland County'],
#  'Owsley County': ['Lee County',
#   'Clay County',
#   'Jackson County',
#   'Breathitt County',
#   'Estill County',
#   'Wolfe County'],
#  'Ozark County': ['Douglas County'],
#  'Ozaukee County': ['Milwaukee County'],
#  'Pacific County': ['Wahkiakum County'],
#  'Page County': ['Montgomery County',
#   'Taylor County',
#   'Fremont County',
#   'Shenandoah County',
#   'Rappahannock County',
#   'Madison County',
#   'Rockingham County',
#   'Greene County',
#   'Harrisonburg city',
#   'Warren County'],
#  'Palo Alto County': ['Emmet County',
#   'Pocahontas County',
#   'Clay County',
#   'Kossuth County'],
#  'Pamlico County': ['Carteret County', 'Craven County'],
#  'Panola County': ['Tate County', 'Quitman County'],
#  'Parke County': ['Vermillion County',
#   'Putnam County',
#   'Fountain County',
#   'Montgomery County'],
#  'Parker County': ['Hood County'],
#  'Pasco County': ['Hernando County'],
#  'Pasquotank County': ['Camden County',
#   'Perquimans County',
#   'Currituck County',
#   'Chowan County'],
#  'Passaic County': ['Bergen County',
#   'Rockland County',
#   'Essex County',
#   'Morris County',
#   'Sussex County',
#   'Hudson County',
#   'New York County'],
#  'Patillas Municipio': ['Arroyo Municipio',
#   'Maunabo Municipio',
#   'Yabucoa Municipio',
#   'Guayama Municipio',
#   'San Lorenzo Municipio',
#   'Cayey Municipio',
#   'Las Piedras Municipio',
#   'Caguas Municipio',
#   'Humacao Municipio',
#   'Juncos Municipio',
#   'Cidra Municipio',
#   'Salinas Municipio',
#   'Gurabo Municipio',
#   'Aguas Buenas Municipio',
#   'Aibonito Municipio',
#   'Comerío Municipio',
#   'Naguabo Municipio',
#   'Trujillo Alto Municipio',
#   'Canóvanas Municipio'],
#  'Patrick County': ['Henry County',
#   'Stokes County',
#   'Floyd County',
#   'Martinsville city',
#   'Carroll County'],
#  'Paulding County': ['Douglas County',
#   'Cobb County',
#   'Polk County',
#   'Haralson County',
#   'Bartow County',
#   'Fulton County',
#   'Defiance County',
#   'Van Wert County',
#   'Putnam County'],
#  'Pawnee County': ['Edwards County',
#   'Rush County',
#   'Johnson County',
#   'Gage County',
#   'Payne County'],
#  'Payette County': ['Gem County'],
#  'Payne County': ['Pawnee County'],
#  'Peach County': ['Houston County',
#   'Crawford County',
#   'Bibb County',
#   'Macon County',
#   'Taylor County',
#   'Twiggs County'],
#  'Pemiscot County': ['Dunklin County', 'Lake County', 'Dyer County'],
#  'Pender County': ['New Hanover County'],
#  'Pendleton County': ['Bracken County',
#   'Grant County',
#   'Harrison County',
#   'Campbell County',
#   'Kenton County',
#   'Robertson County'],
#  'Pennington County': ['Red Lake County'],
#  'Peoria County': ['Stark County', 'Tazewell County'],
#  'Pepin County': ['Buffalo County', 'Dunn County'],
#  'Perkins County': ['Chase County', 'Keith County'],
#  'Perquimans County': ['Pasquotank County',
#   'Chowan County',
#   'Camden County',
#   'Gates County',
#   'Washington County'],
#  'Perry County': ['Hale County',
#   'Dallas County',
#   'Washington County',
#   'Jackson County',
#   'Randolph County',
#   'Franklin County',
#   'Crawford County',
#   'Hancock County',
#   'Spencer County',
#   'Breckinridge County',
#   'Dubois County',
#   'Meade County',
#   'Leslie County',
#   'Knott County',
#   'Breathitt County',
#   'Letcher County',
#   'Forrest County',
#   'Greene County',
#   'Cape Girardeau County',
#   'Jackson County',
#   'Randolph County',
#   'Ste. Genevieve County',
#   'Fairfield County',
#   'Morgan County',
#   'Hocking County',
#   'Muskingum County',
#   'Juniata County',
#   'Cumberland County',
#   'Mifflin County',
#   'Dauphin County',
#   'Decatur County',
#   'Lewis County'],
#  'Person County': ['Granville County',
#   'Caswell County',
#   'Orange County',
#   'Durham County'],
#  'Petersburg city': ['Colonial Heights city',
#   'Hopewell city',
#   'Prince George County',
#   'Chesterfield County',
#   'Dinwiddie County',
#   'Henrico County',
#   'Sussex County',
#   'Charles City County',
#   'Richmond city'],
#  'Peñuelas Municipio': ['Guayanilla Municipio',
#   'Ponce Municipio',
#   'Yauco Municipio',
#   'Adjuntas Municipio',
#   'Guánica Municipio',
#   'Sabana Grande Municipio',
#   'Juana Díaz Municipio',
#   'Jayuya Municipio',
#   'Utuado Municipio',
#   'Maricao Municipio',
#   'Villalba Municipio',
#   'Lares Municipio',
#   'Lajas Municipio',
#   'San Germán Municipio',
#   'Las Marías Municipio',
#   'Santa Isabel Municipio',
#   'Ciales Municipio',
#   'Orocovis Municipio',
#   'Coamo Municipio'],
#  'Phelps County': ['Maries County',
#   'Pulaski County',
#   'Dent County',
#   'Gosper County',
#   'Harlan County',
#   'Kearney County'],
#  'Philadelphia County': ['Delaware County',
#   'Camden County',
#   'Montgomery County',
#   'Gloucester County',
#   'Bucks County'],
#  'Phillips County': ['Coahoma County', 'Lee County', 'Sedgwick County'],
#  'Piatt County': ['De Witt County', 'Macon County', 'Champaign County'],
#  'Pickaway County': ['Franklin County',
#   'Ross County',
#   'Fayette County',
#   'Fairfield County'],
#  'Pickens County': ['Lowndes County',
#   'Cherokee County',
#   'Gilmer County',
#   'Dawson County',
#   'Gordon County',
#   'Bartow County',
#   'Greenville County',
#   'Oconee County',
#   'Transylvania County'],
#  'Pickett County': ['Clinton County',
#   'Fentress County',
#   'Overton County',
#   'Wayne County',
#   'Cumberland County'],
#  'Pierce County': ['Brantley County',
#   'Bacon County',
#   'Wayne County',
#   'Ware County',
#   'Antelope County',
#   'Madison County',
#   'St. Croix County'],
#  'Pike County': ['Crenshaw County',
#   'Bullock County',
#   'Howard County',
#   'Spalding County',
#   'Lamar County',
#   'Upson County',
#   'Meriwether County',
#   'Fayette County',
#   'Scott County',
#   'Brown County',
#   'Pike County',
#   'Dubois County',
#   'Gibson County',
#   'Warrick County',
#   'Daviess County',
#   'Knox County',
#   'Floyd County',
#   'Mingo County',
#   'Martin County',
#   'Dickenson County',
#   'Buchanan County',
#   'Walthall County',
#   'Amite County',
#   'Lincoln County',
#   'Lincoln County',
#   'Ralls County',
#   'Pike County',
#   'Ross County',
#   'Scioto County',
#   'Jackson County',
#   'Sussex County',
#   'Monroe County'],
#  'Pinellas County': ['Hillsborough County'],
#  'Pipestone County': ['Moody County', 'Rock County', 'Murray County'],
#  'Pitt County': ['Greene County', 'Martin County'],
#  'Pittsylvania County': ['Danville city'],
#  'Placer County': ['Nevada County', 'El Dorado County'],
#  'Platte County': ['Wyandotte County',
#   'Clay County',
#   'Buchanan County',
#   'Leavenworth County',
#   'Colfax County',
#   'Madison County'],
#  'Pleasants County': ['Ritchie County',
#   'Tyler County',
#   'Washington County',
#   'Wood County'],
#  'Plymouth County': ['Union County', 'Sioux County', 'Bristol County'],
#  'Pocahontas County': ['Buena Vista County',
#   'Palo Alto County',
#   'Calhoun County',
#   'Humboldt County',
#   'Bath County',
#   'Highland County'],
#  'Poinsett County': ['Craighead County', 'Cross County'],
#  'Pointe Coupee Parish': ['West Feliciana Parish',
#   'West Baton Rouge Parish',
#   'St. Landry Parish'],
#  'Polk County': ['Haralson County',
#   'Floyd County',
#   'Paulding County',
#   'Warren County',
#   'Dallas County',
#   'Story County',
#   'Red Lake County',
#   'Dallas County',
#   'Hickory County',
#   'Greene County',
#   'York County',
#   'Butler County',
#   'Merrick County',
#   'Rutherford County',
#   'Henderson County',
#   'Yamhill County',
#   'Bradley County',
#   'Fannin County',
#   'McMinn County',
#   'Murray County',
#   'San Jacinto County',
#   'Chisago County'],
#  'Ponce Municipio': ['Juana Díaz Municipio',
#   'Peñuelas Municipio',
#   'Villalba Municipio',
#   'Guayanilla Municipio',
#   'Jayuya Municipio',
#   'Santa Isabel Municipio',
#   'Adjuntas Municipio',
#   'Yauco Municipio',
#   'Coamo Municipio',
#   'Orocovis Municipio',
#   'Utuado Municipio',
#   'Ciales Municipio',
#   'Guánica Municipio',
#   'Salinas Municipio',
#   'Sabana Grande Municipio',
#   'Barranquitas Municipio',
#   'Aibonito Municipio',
#   'Maricao Municipio'],
#  'Pontotoc County': ['Union County',
#   'Lee County',
#   'Chickasaw County',
#   'Coal County'],
#  'Pope County': ['Conway County',
#   'Massac County',
#   'Hardin County',
#   'Livingston County',
#   'Johnson County',
#   'Saline County',
#   'Crittenden County',
#   'Douglas County',
#   'Swift County'],
#  'Poquoson city': ['Hampton city',
#   'York County',
#   'Newport News city',
#   'Norfolk city',
#   'Portsmouth city',
#   'Mathews County',
#   'Gloucester County',
#   'Northampton County',
#   'Williamsburg city'],
#  'Portage County': ['Summit County',
#   'Geauga County',
#   'Trumbull County',
#   'Mahoning County'],
#  'Porter County': ['Lake County', 'LaPorte County'],
#  'Portsmouth city': ['Norfolk city',
#   'Chesapeake city',
#   'Hampton city',
#   'Newport News city',
#   'Poquoson city',
#   'Suffolk city',
#   'Virginia Beach city',
#   'Isle of Wight County'],
#  'Posey County': ['Vanderburgh County', 'White County', 'Henderson County'],
#  'Pottawatomie County': ['Riley County',
#   'Seminole County',
#   'Cleveland County'],
#  'Pottawattamie County': ['Mills County'],
#  'Powell County': ['Estill County',
#   'Lee County',
#   'Menifee County',
#   'Montgomery County',
#   'Wolfe County',
#   'Clark County',
#   'Bath County'],
#  'Poweshiek County': ['Iowa County'],
#  'Powhatan County': ['Goochland County',
#   'Amelia County',
#   'Cumberland County',
#   'Chesterfield County',
#   'Richmond city'],
#  'Prairie County': ['Lonoke County', 'Monroe County'],
#  'Preble County': ['Union County',
#   'Montgomery County',
#   'Butler County',
#   'Wayne County'],
#  'Prentiss County': ['Tishomingo County',
#   'Alcorn County',
#   'Tippah County',
#   'Lee County'],
#  'Preston County': ['Garrett County', 'Taylor County', 'Monongalia County'],
#  'Prince Edward County': ['Charlotte County',
#   'Nottoway County',
#   'Lunenburg County',
#   'Cumberland County',
#   'Appomattox County',
#   'Buckingham County'],
#  'Prince George County': ['Hopewell city',
#   'Petersburg city',
#   'Colonial Heights city',
#   'Charles City County',
#   'Henrico County',
#   'Sussex County',
#   'Surry County',
#   'Chesterfield County',
#   'Dinwiddie County',
#   'New Kent County'],
#  "Prince George's County": ['District of Columbia',
#   'Alexandria city',
#   'Arlington County',
#   'Falls Church city',
#   'Anne Arundel County',
#   'Fairfax County',
#   'Fairfax city'],
#  'Prince William County': ['Manassas city',
#   'Manassas Park city',
#   'Fairfax County',
#   'Fairfax city',
#   'Fauquier County',
#   'Stafford County',
#   'Falls Church city',
#   'Alexandria city',
#   'Arlington County'],
#  ...}
